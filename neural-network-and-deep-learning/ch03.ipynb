# %%
import mnist_loader
import network2

# %%
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()

# %%
net = network2.Network([784, 100, 10], cost=network2.CrossEntropyCost)
# net.default_weight_initializer();

# %%
net.SGD(training_data, 60, 10, 0.1, lmbda=5, evaluation_data=test_data,
        monitor_evaluation_cost=True, monitor_evaluation_accuracy=True, monitor_training_cost=True, monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.5475679825353167
# Accuracy on training data: 46205 / 50000
# Cost on evaluation data: 0.655612958405249
# Accuracy on evaluation data: 9253 / 10000
#
# Epoch 1 training complete
# Cost on training data: 0.4316276845743352
# Accuracy on training data: 47220 / 50000
# Cost on evaluation data: 0.6094642371517501
# Accuracy on evaluation data: 9429 / 10000
#
# Epoch 2 training complete
# Cost on training data: 0.3886905141477494
# Accuracy on training data: 47590 / 50000
# Cost on evaluation data: 0.6118553424809969
# Accuracy on evaluation data: 9497 / 10000
#
# Epoch 3 training complete
# Cost on training data: 0.3328687970743005
# Accuracy on training data: 48212 / 50000
# Cost on evaluation data: 0.6022353257613822
# Accuracy on evaluation data: 9597 / 10000
#
# Epoch 4 training complete
# Cost on training data: 0.3127425234127784
# Accuracy on training data: 48381 / 50000
# Cost on evaluation data: 0.6108739247139765
# ...
