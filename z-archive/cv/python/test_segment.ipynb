# %%
import cv_util; reload(cv_util)
# Out:
# <module 'cv_util' from 'cv_util.pyc'>

# %%
import numpy as np
from skimage import data, segmentation, color, io
from skimage.future import graph
from matplotlib import pyplot as plt
from skimage.segmentation import felzenszwalb
import time

# %matplotlib inline

# %%
path = '/home/taot/AI/datasets/PASCAL_VOC/VOCdevkit/VOC2012/JPEGImages'

# %%
# img = data.coffee()
img = io.imread(path + '/2007_006946.jpg')
start = time.time()
segments = felzenszwalb(img, scale=3.0, sigma=0.8, min_size=300)
print(time.time() - start)
# Out:
# 0.207998037338

# %%
colored_segments = cv_util.get_colored_segmentation(segments)

# %%
fig, ax = plt.subplots(nrows=3, sharex=True, sharey=True, figsize=(9, 12))
ax[0].imshow(img)
ax[1].imshow(segments)
ax[2].imshow(colored_segments)
plt.tight_layout()
